# %% [markdown]
# Name | Matr.Nr. | Due Date
# :--- | ---: | ---:
# Azat Vakhitov | 12148222 | 06.02.2023, 08:00

# %% [markdown]
# <h1 style="color:rgb(0,120,170)">Hands-on AI I</h1>
# <h2 style="color:rgb(0,120,170)">Unit 7 &ndash; Tricks of the Trade</h2>

# %% [markdown]
# <b>Authors:</b> Schlüter, Rumetshofer, Schörgenhumer<br>
# <b>Date:</b> 23-01-2023
#
# This file is part of the "Hands-on AI I" lecture material. The following copyright statement applies to all code within this file.
#
# <b>Copyright statement:</b><br>
# This material, no matter whether in printed or electronic form, may be used for personal and non-commercial educational use only. Any reproduction of this material, no matter whether as a whole or in parts, no matter whether in printed or in electronic form, requires explicit prior acceptance of the authors.

# %% [markdown]
# <h3 style="color:rgb(0,120,170)">How to use this notebook</h3>
#
# This notebook is designed to run from start to finish. There are different tasks (displayed in <span style="color:rgb(248,138,36)">orange boxes</span>) which require your contribution (in form of code, plain text, ...). Most/All of the supplied functions are imported from the file <code>u7_utils.py</code> which can be seen and treated as a black box. However, for further understanding, you can look at the implementations of the helper functions. In order to run this notebook, the packages which are imported at the beginning of <code>u7_utils.py</code> need to be installed.

# %%
# Import pre-defined utilities specific to this notebook.
import u7_utils as u7

# Import additional utilities needed in this notebook.
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
import torch

from pathlib import Path

# Set default plotting style.
sns.set()

# Setup Jupyter notebook (warning: this may affect all Jupyter notebooks running on the same Jupyter server).
u7.setup_jupyter()
# Out:
#     <style>
#         .output_png {
#             display: table-cell;
#             text-align: center;
#             vertical-align: middle;
#         }
#         .jp-RenderedImage {
#             display: table-cell;
#             text-align: center;
#             vertical-align: middle;
#         }
#     </style>
#     <p>Setting up notebook ... finished.</p>

# %% [markdown]
# <h2>Exercise 1</h2>

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 1.1. [5 Points]</b>
#     <ul>
#         <li>In this notebook, you will be working with the provided datatset <code>resources/redspace_and_trees</code>.</li>
#         <li>Specify the path and download the images of this dataset.</li>
#         <li>Load the dataset, reserving 15% for validation and enabling data augmentation.</li>
#     </ul>
# </div>

# %%
dataset_name = "redspace_and_trees"
dataset_path = Path(f"resources/{dataset_name}")
dataset_path.mkdir(parents=True, exist_ok=True)
u7.download_all_images(dataset_path)
dataset = u7.load_image_dataset(
    dataset_path,
    valid_size=0.15,  # keep 15% for validation
    batch_size=32,   # reduce if you run out of RAM
    augment=True     # whether to use augmentation
)
# Out:
# Downloading 'redspace' images:   0%|          | 0/99 [00:00<?, ?it/s]
# ignored 99 'redspace' images because they already exist
# Downloading 'trees' images:   0%|          | 0/100 [00:00<?, ?it/s]
# ignored 100 'trees' images because they already exist

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 1.2. [5 Points]</b>
#     <ul>
#         <li>Plot 9 example images in 3 rows.</li>
#     </ul>
# </div>

# %%
u7.set_seed(100)
u7.plot_image_dataset(dataset_path, nitems=9, nrows=3, size=128)

# %% [markdown]
# <h2>Exercise 2</h2>

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 2.1. [5 Points]</b>
#     <ul>
#         <li>Using <code>u7.create_cnn()</code>, create a <b>pretrained</b> CNN with 34 layers and the number of classes set according to your dataset (the other settings do not matter).</li>
#         <li>Store the model in a variable called <code>model</code>.</li>
#     </ul>
# </div>

# %%
u7.set_seed(100)
model = u7.create_cnn(
    num_classes=dataset.c,
    num_layers=34,      # try larger models: 18, 34, 50, 101 or 152 (these are already predefined for you)
    # batchnorm=False,   # whether to use batch normalization
    # dropout=0,         # try 0.5 for 50% dropout or 0.25 for 25% dropout
    # residuals=False,   # whether to use residual connections
    # pretrained=False   # whether to use pretrained weights
)

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Important:</b> Plot the weights of the first layer (already done, only need to execute the cell).
# </div>

# %%
weights = u7.visualize_cnn_filters(model, ncols=8, image_size=2)

# %% [markdown]
# <h2>Exercise 3</h2>
#
# Using the dataset that you loaded in Exercise 1, perform the following tasks:

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 3.1. [5 Points]</b>
#     <ul>
#         <li>Create a CNN with 34 layers, no dropout, no batch normalization, no residuals, and no pretraining, using <code>u7.create_cnn()</code>.</li>
#         <li><b>Important:</b> Set the seed to 100 before calling <code>u7.create_cnn()</code>.</li>
#     </ul>
# </div>

# %%
u7.set_seed(100)
model = u7.create_cnn(
    num_classes=dataset.c,
    num_layers=34,      # try larger models: 18, 34, 50, 101 or 152 (these are already predefined for you)
    batchnorm=False,   # whether to use batch normalization
    dropout=0,         # try 0.5 for 50% dropout or 0.25 for 25% dropout
    residuals=False,   # whether to use residual connections
    pretrained=False   # whether to use pretrained weights
)
loss = torch.nn.functional.cross_entropy

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 3.2. [5 Points]</b>
#     <ul>
#         <li>Plot the weights of the first layer and store them in a variable called <code>weights_before_training</code>.</li>
#     </ul>
# </div>

# %%
weights_before_training = u7.visualize_cnn_filters(model, ncols=8, image_size=2)

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 3.3. [5 Points]</b>
#     <ul>
#         <li>Train the model for 6 iterations/epochs, with a constant learning rate of 0.001 (no learning rate schedule), momentum of 0.9, and without plotting curves, using <code>u7.run_gradient_descent()</code>.</li>
#         <li>Hint: You may omit the validation set to speed up the computation, as it is not needed.</li>
#     </ul>
# </div>

# %%
u7.run_gradient_descent(
    model=model,
    loss=loss,
    training_set=dataset.train,
    valid_set=dataset.valid,
    iterations=6,         # number of epochs
    learning_rate=0.001,  # base learning rate
    momentum=0.9,         # base momentum
    lr_schedule=None,     # try "linear", "onecycle", "steps"
    plot_curves=False
);
# Out:
#   0%|          | 0/170 [00:00<?, ?it/s]
# Epoch  1 finished with training loss: 0.699240 and validation loss: 0.697410
# Epoch  2 finished with training loss: 0.691859 and validation loss: 0.694629
# Epoch  3 finished with training loss: 0.688740 and validation loss: 0.695145
# Epoch  4 finished with training loss: 0.677344 and validation loss: 0.696025
# Epoch  5 finished with training loss: 0.642003 and validation loss: 0.698327
# Epoch  6 finished with training loss: 0.568990 and validation loss: 0.697393

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 3.4. [5 Points]</b>
#     <ul>
#         <li>Plot the weights of the first layer again and store them in a variable called <code>weights_after_training</code>.</li>
#     </ul>
# </div>

# %%
weights_after_training = u7.visualize_cnn_filters(model, ncols=8, image_size=2)

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 3.5. [5 Points]</b>
#     <ul>
#         <li>Compare the filters plotted before and after training. Do you see any difference? Did the filters change visibly during training?</li>
#     </ul>
# </div>

# %% [markdown]
# your answer goes here

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Important:</b> Print the absolute difference of weights before and after training (already done, only need to execute the cell). This might help you in answering the above question.
# </div>

# %%
(weights_before_training - weights_after_training).abs().sum().item()
# Out:
# 5.104891300201416

# %% [markdown]
# <h2>Exercise 4</h2>
#
# Similar to before, perform the following tasks:

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 4.1. [5 Points]</b>
#     <ul>
#         <li>Create a CNN with 34 layers, no dropout, <b>with</b> batch normalization, <b>with</b> residuals, and no pretraining, using <code>u7.create_cnn()</code>.</li>
#         <li><b>Important:</b> Set the seed to 100 before calling <code>u7.create_cnn()</code>.</li>
#     </ul>
# </div>

# %%
u7.set_seed(100)
model = u7.create_cnn(
    num_classes=dataset.c,
    num_layers=34,      # try larger models: 18, 34, 50, 101 or 152 (these are already predefined for you)
    batchnorm=True,   # whether to use batch normalization
    dropout=0,         # try 0.5 for 50% dropout or 0.25 for 25% dropout
    residuals=True,   # whether to use residual connections
    pretrained=False   # whether to use pretrained weights
)
loss = torch.nn.functional.cross_entropy

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 4.2. [5 Points]</b>
#     <ul>
#         <li>Plot the weights of the first layer and store them in a variable called <code>weights_before_training</code>.</li>
#     </ul>
# </div>

# %%
weights_before_training = u7.visualize_cnn_filters(model, ncols=8, image_size=2)

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 4.3. [5 Points]</b>
#     <ul>
#         <li>Train the model for 6 iterations, with a constant learning rate of 0.001 (no learning rate schedule), momentum of 0.9, and without plotting curves, using <code>u7.run_gradient_descent()</code>.</li>
#         <li>Hint: You may omit the validation set to speed up the computation, as it is not needed.</li>
#     </ul>
# </div>

# %%
u7.run_gradient_descent(
    model=model,
    loss=loss,
    training_set=dataset.train,
    valid_set=dataset.valid,
    iterations=6,         # number of epochs
    learning_rate=0.001,  # base learning rate
    momentum=0.9,         # base momentum
    lr_schedule=None,     # try "linear", "onecycle", "steps"
    plot_curves=False
);
# Out:
#   0%|          | 0/170 [00:00<?, ?it/s]
# Epoch  1 finished with training loss: 0.739931 and validation loss: 0.657588
# Epoch  2 finished with training loss: 0.382472 and validation loss: 0.494793
# Epoch  3 finished with training loss: 0.214771 and validation loss: 0.394355
# Epoch  4 finished with training loss: 0.120032 and validation loss: 0.421897
# Epoch  5 finished with training loss: 0.089186 and validation loss: 0.433177
# Epoch  6 finished with training loss: 0.159161 and validation loss: 1.031697

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 4.4. [5 Points]</b>
#     <ul>
#         <li>Plot the weights of the first layer again and store them in a variable called <code>weights_after_training</code>.</li>
#     </ul>
# </div>

# %%
weights_after_training = u7.visualize_cnn_filters(model, ncols=8, image_size=2)

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 4.5. [5 Points]</b>
#     <ul>
#         <li>Compare the filters plotted before and after training. Do you see any difference? Did the filters change visibly during training?</li>
#     </ul>
# </div>

# %% [markdown]
# your answer goes here

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Important:</b> Print the absolute difference of weights before and after training (already done, only need to execute the cell). This might help you in answering the above question.
# </div>

# %%
(weights_before_training - weights_after_training).abs().sum().item()
# Out:
# 25.808427810668945

# %% [markdown]
# <h2>Exercise 5</h2>
#
# Magic vs. you!

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 5.1. [5 Points]</b>
#     <ul>
#         <li>Using <code>u7.perform_magic()</code>, calculate the error rate on the dataset specified in the beginning of the notebook (use the same path).</li>
#         <li>Use a validation size of 15% and let it run for 2 iterations/epochs. All other settings should use the default values.</li>
#         <li><b>Important:</b> Set the seed to 100 before calling <code>u7.perform_magic()</code>.</li>
#     </ul>
# </div>

# %%
u7.set_seed(100)
result = u7.perform_magic(dataset_path, valid_size=0.15)
# Out:
# C:\Users\azatv\anaconda3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\azatv\anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.891565</td>
#       <td>0.451963</td>
#       <td>0.241379</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.488684</td>
#       <td>0.264453</td>
#       <td>0.103448</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.316437</td>
#       <td>0.300679</td>
#       <td>0.103448</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.239588</td>
#       <td>0.444043</td>
#       <td>0.103448</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 5.2. [30 Points]</b>
#     <ul>
#         <li>Now it's your time! Can you get a lower error rate on the validation set than the magic from above?</li>
#         <li>Use the same validation size of 15% when manually loading the dataset with <code>u7.load_image_dataset()</code>. All other settings are completely up to you!</li>
#         <li><b>Important:</b> Set the seed to 100 before all following calls:
#             <ul>
#                 <li><code>u7.load_image_dataset()</code></li>
#                 <li><code>u7.create_cnn()</code> (if you want to use this utility function, you can also set up your own architecture, but make sure to set the seed before that, too)</li>
#                 <li><code>u7.run_gradient_descent()</code></li>
#             </ul>
#         </li>
#         <li>Note: In the unlikely case that <code>u7.perform_magic()</code> from above has an error rate of 0, try to get as close as possible to this result (within about 5% error rate).</li>
#     </ul>
# </div>

# %%
u7.set_seed(100)
dataset = u7.load_image_dataset(
    dataset_path,
    valid_size=0.15,  # keep 15% for validation
    batch_size=42,   # reduce if you run out of RAM
    augment=True     # whether to use augmentation
)
model = u7.create_cnn(
    num_classes=dataset.c,
    num_layers=34,      # try larger models: 18, 34, 50, 101 or 152 (these are already predefined for you)
    batchnorm=True,   # whether to use batch normalization
    dropout=0.5,         # try 0.5 for 50% dropout or 0.25 for 25% dropout
    residuals=True,   # whether to use residual connections
    pretrained=True   # whether to use pretrained weights
)

loss = torch.nn.functional.cross_entropy
u7.run_gradient_descent(
    model=model,
    loss=loss,
    training_set=dataset.train,
    valid_set=dataset.valid,
    iterations=20,         # number of epochs
    learning_rate=0.01,  # base learning rate
    momentum=0.2,         # base momentum
    lr_schedule="steps",     # try "linear", "onecycle", "steps"
    plot_curves=True
);
# Out:
#   0%|          | 0/170 [00:00<?, ?it/s]
# Epoch  1 finished with training loss: 1.282918 and validation loss: 0.754809
# Epoch  2 finished with training loss: 0.864242 and validation loss: 0.104179
# Epoch  3 finished with training loss: 0.080156 and validation loss: 0.760450
# Epoch  4 finished with training loss: 0.320890 and validation loss: 0.235070
# Epoch  5 finished with training loss: 0.424110 and validation loss: 0.140426
# Epoch  6 finished with training loss: 0.981838 and validation loss: 3.260134
# Epoch  7 finished with training loss: 2.854585 and validation loss: 4.725209
# Epoch  8 finished with training loss: 3.052306 and validation loss: 0.183465
# Epoch  9 finished with training loss: 4.142541 and validation loss: 7.217077
# Epoch 10 finished with training loss: 0.093541 and validation loss: 1.593789
# Epoch 11 finished with training loss: 0.771342 and validation loss: 0.156460
# Epoch 12 finished with training loss: 3.666153 and validation loss: 1.557158
# Epoch 13 finished with training loss: 3.835186 and validation loss: 12.581364
# Epoch 14 finished with training loss: 1.259436 and validation loss: 10.712518
# Epoch 15 finished with training loss: 1.467031 and validation loss: 8.323234
# Epoch 16 finished with training loss: 0.456672 and validation loss: 6.777091
# Epoch 17 finished with training loss: 0.171975 and validation loss: 5.315528
# Epoch 18 finished with training loss: 1.210749 and validation loss: 4.982484
# Epoch 19 finished with training loss: 0.342933 and validation loss: 3.058731
# Epoch 20 finished with training loss: 0.358869 and validation loss: 2.552107

# %%
import torch
import torchvision
torch.cuda.is_available()
# Out:
# True
